# %%
from pyrosm import OSM, get_data
# Out:
# /home/hentenka/.conda/envs/sustainability/lib/python3.8/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1dev-CAPI-1.14.1) is incompatible with the GEOS version PyGEOS was compiled with (3.9.1-CAPI-1.14.2). Conversions between both will be slow.
#   warnings.warn(

# %%
osm = OSM(get_data("helsinki_pbf"))
n = osm.get_network()
n.plot()
# Out:
# <AxesSubplot:>
